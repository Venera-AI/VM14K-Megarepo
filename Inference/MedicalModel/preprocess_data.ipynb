# %%
from uuid import uuid4
import json

# %%
output_path = "tmp/data-processed-cleaned2/data-processed-shuffled0.jsonl"
shuffled_path = "tmp/data-processed-cleaned2/data-processed-shuffled1.jsonl"
shuffled_path2 = "tmp/data-processed-cleaned2/data-processed-shuffled2.jsonl"

# %%
import re

def better_question(question: str) -> str:
    question_num_regex = r"^[Cc](?:a|á|à|ả|ã|ạ|â|ấ|ầ|ẩ|ẫ|ậ|ă|ắ|ằ|ẳ|ẵ|ặ)[Uu](?:|ù|ú|ủ|ũ|ụ|ư|ứ|ừ|ử|ữ|ự)\s*\D+\s*\d+\W*"
    return re.sub(question_num_regex, "", question.strip(), 1)


def better_options(options: list[str]) -> list[str]:
    scan_regex = r"^\s*[A-Ga-g]{1}\W+.+$"
    delete_regex = r"^\s*[A-Ga-g]{1}\W+"
    
    check_list = [0] * (ord('G') - ord('A') + 1)
    results = []
    replaced = 0
    for option in options:
        choice_char = ord(option.strip()[0].upper()) - ord('A')
        if 0 <= choice_char and choice_char < len(check_list) and check_list[choice_char] < 2:
            check_list[choice_char] += 1
        if re.match(scan_regex, option):
            results.append(re.sub(delete_regex, "", option, 1))
            replaced += 1
        else:
            results.append(option)
    if replaced == len(options) and all(check < 2 for check in check_list):
        return results
    else:
        return options

# %%
from csv import DictReader

rows = []
last = 0
for i in range(3):
    with open(f"inputs2/part{i}.csv") as csv_file:
        reader = DictReader(csv_file)
        rows.extend({**row, "file": i} for row in reader)
        print("Inserted:", len(rows) - last)
        last = len(rows)

# rows = rows[:300]
mapper = {
    "Hard": "Hard",
    "Easy": "Easy",
    "Moderate": "Medium",
    "Challenging": "Challenging",
    "Medium": "Medium",
    "Very Hard": "Challenging",
}
valid_difficulty = set(["Easy", "Medium", "Hard", "Challenging"])

f = open("errors.jsonl", 'w')

def transform(i, row):
    try:
        id = uuid4().hex
        options = [row[key] for key, value in row.items() if key.startswith("option") and value]
        cleaned_options = better_options(options)
        question = row["question"]
        cleaned_question = better_question(row["question"])
        if cleaned_question != question:
            print(f"{id}: {question} -> {cleaned_question}")
        if options != cleaned_options:
            print(f"{id}: {options} -> {cleaned_options}")

        res = {
            "id": id,
            "difficulty_level": mapper[row["difficultLevel"].strip()],
            "medical_topic": [item.strip() for item in row["medicalTopic"].split(",")],
            "question": cleaned_question,
            "options": cleaned_options,
            "option_map": [i for i in range(len(options))],
            "answer": row["correctOption"][-1],
            "answer_index": ord(row["correctOption"][-1]) - ord("A"),
        }
        assert len(res["question"])
        assert res["difficulty_level"] in valid_difficulty
        assert len(res["medical_topic"])
        assert res["answer_index"] >= 0
        assert res["answer_index"] < len(res["options"])
        return res
    except Exception as e:
        json.dump(row, f, ensure_ascii=False)
        f.write('\n')
        # print(i, row)
        # print(e)
        # raise e
        return None

rows = [
    transform(i, row)
    for i, row in enumerate(rows)
]

print(rows[0])
rows = list(filter(lambda row: row is not None, rows))
print("Final len:", len(rows))
f.close()
# Out:
# Inserted: 1924
# Inserted: 1999
# Inserted: 1416
# 2bf07cb12baa41bebe61750a3fee94b3: ['A. Morphin và Cocain', 'B. Morphinvà Heroin', 'C. Heroin và Cocain', 'D. Morphin và Codein'] -> ['Morphin và Cocain', 'Morphinvà Heroin', 'Heroin và Cocain', 'Morphin và Codein']
# d46d8bf93e3c4fe9bb4bf1c1698c3d53: ['A. Amphetamin', 'B. Aconitin', 'C.Quinine', 'D. Cocain'] -> ['Amphetamin', 'Aconitin', 'Quinine', 'Cocain']
# 39cc4675d3ec4860ae6ba237a9e8e4fb: ['A. Hoa trắng, hạt màu vàng nhạt', 'B.\nHoa tím, hạt màu xám', 'C. Hoa tím, hạt đen tím', 'D. Hoa hồng, hạt màu tím'] -> ['Hoa trắng, hạt màu vàng nhạt', 'Hoa tím, hạt màu xám', 'Hoa tím, hạt đen tím', 'Hoa hồng, hạt màu tím']
# 4fafb4608e8b462ba1eb34ae76cccaa3: ['a. Màng căng đàn hồi chịu tác dụng của một lực mạnh.', 'b. Dây kim loại căng chịu tác dụng của một lực tuần hoàn.', 'c. Một bản thạch anh áp điện chịu tác dụng của một hiệu điện thế xoay chiều tần số cao hơn 20.000Hz.', 'd. Cột không khí bị nén bởi một lực nào đó.'] -> ['Màng căng đàn hồi chịu tác dụng của một lực mạnh.', 'Dây kim loại căng chịu tác dụng của một lực tuần hoàn.', 'Một bản thạch anh áp điện chịu tác dụng của một hiệu điện thế xoay chiều tần số cao hơn 20.000Hz.', 'Cột không khí bị nén bởi một lực nào đó.']
# 934c42f8e7f14d5fbf0e8c86e662f94a: ['a. Tần số nhỏ hơn 20.000Hz', 'b. Là sóng ngang gây đứt gẫy môi trường', 'c. Không thể truyền thẳng khi bị cản', 'd. Qua môi trường sẽ bị hấp thụ làm giảm cường độ'] -> ['Tần số nhỏ hơn 20.000Hz', 'Là sóng ngang gây đứt gẫy môi trường', 'Không thể truyền thẳng khi bị cản', 'Qua môi trường sẽ bị hấp thụ làm giảm cường độ']
# 9dce941eefab4d8298a5e4aa61b8cb5e: ['a. Tỷ lệ thuận chiều dày môi trường', 'b. Không phụ thuộc tần số siêu âm', 'c. Tỷ lệ nghich mật độ môi trường', 'd. Càng nhiều khi tốc độ lan truyền siêu âm càng nhỏ.'] -> ['Tỷ lệ thuận chiều dày môi trường', 'Không phụ thuộc tần số siêu âm', 'Tỷ lệ nghich mật độ môi trường', 'Càng nhiều khi tốc độ lan truyền siêu âm càng nhỏ.']
# 256ccaee202e4b3aa9e43f35963e90b1: ['a. Thuốc tím 1/1000-1/10000', 'b. phenol', 'c.oxy già', 'd.cồn 90%'] -> ['Thuốc tím 1/1000-1/10000', 'phenol', 'oxy già', 'cồn 90%']
# 58efdd43878647268a526452cce5f433: ['a. U giáp lành tính', 'b. Giả u', 'c. U giáp ác tính', 'd. Dạng nốt'] -> ['U giáp lành tính', 'Giả u', 'U giáp ác tính', 'Dạng nốt']
# bfb5185a641c4b76a12937d44791462e:  Biện pháp dự phòng cấp 2 để phòng bệnh lây theo đường da, niêm mạc do súc vật truyền sang người là phát hiện sớm động vật mắc bệnh và xử lý kịp thời. -> Biện pháp dự phòng cấp 2 để phòng bệnh lây theo đường da, niêm mạc do súc vật truyền sang người là phát hiện sớm động vật mắc bệnh và xử lý kịp thời.
# 8bd25a9b28234dbfa5b6db33d63eec6d: Cách xác định tỷ trọng của siro thuốc khi đo bằng picnomet là:  -> Cách xác định tỷ trọng của siro thuốc khi đo bằng picnomet là:
# 8bd25a9b28234dbfa5b6db33d63eec6d: ['A. d=m/v', 'B. d=M1/M', 'C. d= (m3-m1)/(m2-m1)', 'D. Đọc trên thang đo của dụng cụ.'] -> ['d=m/v', 'd=M1/M', 'd= (m3-m1)/(m2-m1)', 'Đọc trên thang đo của dụng cụ.']
# 87d08108c78c4a1fa2435c0a6ccfeff9: Câu 1 Estrogen được bài tiết từ các tế bào nang trứng KHÔNG có chức năng nào dưới đây? -> Estrogen được bài tiết từ các tế bào nang trứng KHÔNG có chức năng nào dưới đây?
# 977515c434b041ba96837a347ed8bf3a: Câu 1: Áp suất riêng phần của CO­2 ở các tế bào:
# 1. Tỷ lệ thuận với nồng độ CO­2
# 2. Tỷ lệ nghịch với nồng độ H+
# 3. Tỷ lệ thuận với nồng độ O2
# 4. Tỷ lệ thuận với áp suất riêng phần của O2
# 5. Tỷ lệ nghịch với pH
# Chọn tập hợp đúng: -> Áp suất riêng phần của CO­2 ở các tế bào:
# 1. Tỷ lệ thuận với nồng độ CO­2
# 2. Tỷ lệ nghịch với nồng độ H+
# 3. Tỷ lệ thuận với nồng độ O2
# 4. Tỷ lệ thuận với áp suất riêng phần của O2
# 5. Tỷ lệ nghịch với pH
# Chọn tập hợp đúng:
# 5e02d1e138b94f37bda81880daac5579: Câu 1. chọn đáp án đúng nhất: ý nào dưới đây đúng vs đặc điểm hấp thu các chất tạo niêm mạc ruột non? -> chọn đáp án đúng nhất: ý nào dưới đây đúng vs đặc điểm hấp thu các chất tạo niêm mạc ruột non?
# 5e02d1e138b94f37bda81880daac5579: ['A glucose được vận chuyển tích cực thứ phát', 'C acid tan đc vận chuển bằng cơ chế tích cực'] -> ['glucose được vận chuyển tích cực thứ phát', 'acid tan đc vận chuển bằng cơ chế tích cực']
# 99b2e499d91244428501222ce5992e22: Câu 10: Chọn ý sai, đánh giá mất nước nặng nếu trẻ có ỉa chảy gồm -> Chọn ý sai, đánh giá mất nước nặng nếu trẻ có ỉa chảy gồm
# 57d01e2d08e2480389bff0fb7e709e1e: Câu 10: Đặc điểm điển hình của sung huyết tĩnh là gì? -> Đặc điểm điển hình của sung huyết tĩnh là gì?
# 57d01e2d08e2480389bff0fb7e709e1e: ['A. Dòng máu chảy chậm hẳn lại', 'B. Chất dịch trong máu thoát vào mô kẽ', 'C. Chất dịch thoát ra ngoài mạnh mẽ', 'D. Lòng mạch bị rộng hắn ra'] -> ['Dòng máu chảy chậm hẳn lại', 'Chất dịch trong máu thoát vào mô kẽ', 'Chất dịch thoát ra ngoài mạnh mẽ', 'Lòng mạch bị rộng hắn ra']
# 6fb086276d284e9da459f27baf02897f: Câu 10: Điều nào sau đây là đúng về tổn thương tiêu hóa trong Ban xuất huyết Henoch- Schonlein? -> Điều nào sau đây là đúng về tổn thương tiêu hóa trong Ban xuất huyết Henoch- Schonlein?
# 7f34d4e0bc134b489fc3d0048ec9db22: Câu 10: MSH có tác dụng kích thích hoạt động: -> MSH có tác dụng kích thích hoạt động:
# 7543d52bf6ea439fb5e39bc4720c5005: Câu 10:Đáp ứng miễn dịch là -> Đáp ứng miễn dịch là
# cab86deaff4d43f193a7ba3fde2312d6: Câu 10. Chất dùng GIẢI ĐỘC Paracetamol: -> Chất dùng GIẢI ĐỘC Paracetamol:
# 746c099183f048568661f0aed8cee44e: Câu 10. Chất lưỡi màu trắng nhạt sưng to do: -> Chất lưỡi màu trắng nhạt sưng to do:
# 746c099183f048568661f0aed8cee44e: ['A. Thấp nhiệt bên trong', 'B. Nhiệt độc mạnh', 'C. Thận Tỳ dương hư', 'D. Tỳ Vị hư hàn'] -> ['Thấp nhiệt bên trong', 'Nhiệt độc mạnh', 'Thận Tỳ dương hư', 'Tỳ Vị hư hàn']
# 5fb5bc74b3c74ace90ebe4f3cd977269: Câu 10. Có bao nhiêu đường kinh chính: -> Có bao nhiêu đường kinh chính:
# 5fb5bc74b3c74ace90ebe4f3cd977269: ['A. 15', 'B. 13', 'C. 14', 'D. 12'] -> ['15', '13', '14', '12']
# f06eeea3b28641e093bd62ed7b893175: Câu 101: Hình ảnh vi thể của ung thư biểu mô vảy không có đặc điểm nào sau: -> Hình ảnh vi thể của ung thư biểu mô vảy không có đặc điểm nào sau:
# c92dfb066dd342168ce03f851c5617f1: Câu 106: Kháng sinh nào ức chế tổng hợp protein do tác động vào tiểu phần 50S của ribosom? -> Kháng sinh nào ức chế tổng hợp protein do tác động vào tiểu phần 50S của ribosom?
# c2a50b9214e745918d886ee151dba19b: Câu 106. Liều nào của Dopamin sau đây được gọi là “Liều thận”: -> Liều nào của Dopamin sau đây được gọi là “Liều thận”:
# b62418fd5d454921bd6ca00ac0e2a273: Câu 11: Di chứng hẹp, hở van 2 lá, van động mạch chủ trong thấp tim hay gặp ở đâu? -> Di chứng hẹp, hở van 2 lá, van động mạch chủ trong thấp tim hay gặp ở đâu?
# b62418fd5d454921bd6ca00ac0e2a273: ['A: Viêm nội tâm mạc', 'B: Viêm cơ nội tâm mạc', 'C: Viêm cơ tim', 'D: Viêm màng ngoài tim'] -> ['Viêm nội tâm mạc', 'Viêm cơ nội tâm mạc', 'Viêm cơ tim', 'Viêm màng ngoài tim']
# 7c872d15779147779546c017966fb8f1: Câu 11: Protid chuyển hóa thành lipid là do: -> Protid chuyển hóa thành lipid là do:
# 7c872d15779147779546c017966fb8f1: ['A. Một số acid amin chuyển hóa thành a cetoglutarate là nguyên liệu tổng hợp acid béo.', 'B. Aspartat chuyển hóa thành các sản phẩm trung gian trong chu trình Urê.', 'C. Một số acid amin chuyển hóa thành acetyl CoA, acetyl CoA là nguyên liệu tổng hợp acid béo.', 'D. Các acid amin chuyển hóa thành pyuvat rồi thành Lactat là nguyên liệu tổng hợp acid béo.'] -> ['Một số acid amin chuyển hóa thành a cetoglutarate là nguyên liệu tổng hợp acid béo.', 'Aspartat chuyển hóa thành các sản phẩm trung gian trong chu trình Urê.', 'Một số acid amin chuyển hóa thành acetyl CoA, acetyl CoA là nguyên liệu tổng hợp acid béo.', 'Các acid amin chuyển hóa thành pyuvat rồi thành Lactat là nguyên liệu tổng hợp acid béo.']
# dd5dd56368394bc6b96cd0af6a977d96: Câu 1106 Xử trí nào không nên làm trong trường hợp thai trong ổ bụng: -> Xử trí nào không nên làm trong trường hợp thai trong ổ bụng:
# 5315a49ce74e4155b25e16ead83eff8d: Câu 1149 Tất cả những câu sau đây về nhau tiền đạo đều đúng, NGOẠI TRỪ: -> Tất cả những câu sau đây về nhau tiền đạo đều đúng, NGOẠI TRỪ:
# bd92ee962aaf4d53b9643666c889e3aa: Câu 116: AFB không bắt màu thuốc nhuộm thông thường do: -> AFB không bắt màu thuốc nhuộm thông thường do:
# 64963539190d48bfae74736a5e5919ce: Câu 117: Nguy cơ suy tạng nào cần theo dõi sát nhất trên bệnh nhân dị ứng thuốc nặng? -> Nguy cơ suy tạng nào cần theo dõi sát nhất trên bệnh nhân dị ứng thuốc nặng?
# b8a6fcdca7c84bb9bc38a5f85af08e0c: Câu 117. Để so bộ xác định người bị hội chứng klinerfelter thì xét nghiệm đơn giản nhất anh (cái) có thể vận dụng được là -> Để so bộ xác định người bị hội chứng klinerfelter thì xét nghiệm đơn giản nhất anh (cái) có thể vận dụng được là
# b8a6fcdca7c84bb9bc38a5f85af08e0c: ['A. Kayotupe.', 'B. Vat the Barr.', 'C. Vat the Y.', 'D. Định lượng nội tiết tố nam Testosterol'] -> ['Kayotupe.', 'Vat the Barr.', 'Vat the Y.', 'Định lượng nội tiết tố nam Testosterol']
# 9c1e1a02ed8842b7b66d5c034b87935f: Câu 1172 Xử trí rau tiền đạo trung tâm ra máu khi chuyển dạ tại tuyến y tế cơ sở là: -> Xử trí rau tiền đạo trung tâm ra máu khi chuyển dạ tại tuyến y tế cơ sở là:
# 0ba72548acba4ac48acd74a16b595103: Câu 119 thể loại cứu chữa binh lính tại trạm quan y tiểu đoàn là ? -> thể loại cứu chữa binh lính tại trạm quan y tiểu đoàn là ?
# ccfadc52f5494614b7bf44fd47ed16ed: Câu 12: Nơron có các đặc điểm sau, TRỪ MỘT: -> Nơron có các đặc điểm sau, TRỪ MỘT:
# f85f626070c64411a27e18726a394e17: Câu 12:Bệnh ghẻ do ký sinh trùng nào gây bệnh: -> Bệnh ghẻ do ký sinh trùng nào gây bệnh:
# f85f626070c64411a27e18726a394e17: ['A.Trychophyton rubrum .', 'B.Sarcoptes scabies hominis .', 'C.Trypanosoma spp .', 'D.Candida albicans .'] -> ['Trychophyton rubrum .', 'Sarcoptes scabies hominis .', 'Trypanosoma spp .', 'Candida albicans .']
# ec80f0706c984587ab679a60afac958b: Câu 12. Hạ đường huyết không nhận biết xảy ra thường xuyên ở những bệnh nhân nào? -> Hạ đường huyết không nhận biết xảy ra thường xuyên ở những bệnh nhân nào?
# 49f848f493224e51b1a3e2ba748e182a: Câu 121: Điều kiện thuận lợi dễ mắc bệnh nấm hắc lào? -> Điều kiện thuận lợi dễ mắc bệnh nấm hắc lào?
# 859dba536dbe416a8ee5f66e24a3b92c: Câu 123 Các vết thương phần mềm chống chỉ định phẫu thuật là? -> Các vết thương phần mềm chống chỉ định phẫu thuật là?
# 6a4128d951f34259a46056fbd02c9e28: Câu 1236 Khi mổ lấy thai vì nhau bong non nếu thấy tử cung tím đen có khi lan ra tới dây chằng rộng do phong huyết tử cung nhau, tử cung thu hồi tốt, hướng xử trí tiếp là: -> Khi mổ lấy thai vì nhau bong non nếu thấy tử cung tím đen có khi lan ra tới dây chằng rộng do phong huyết tử cung nhau, tử cung thu hồi tốt, hướng xử trí tiếp là:
# f4520c57e091435892147a89f12244fd: Câu 1270 Các câu dưới đây đều đúng khi nói về vỡ tử cung, NGOẠI TRỪ: -> Các câu dưới đây đều đúng khi nói về vỡ tử cung, NGOẠI TRỪ:
# 2f73e08b1ee84a00bf32cb12c1e19bfd: Câu 130: Vi khuẩn kháng thuốc kháng sinh theo cơ chế: -> Vi khuẩn kháng thuốc kháng sinh theo cơ chế:
# 010202d874784016a010850d350f4d14: Câu 130. Một trong những tiêu chí của sản phẩm được kỳ vọng được phân loại theo yếu tố mở rộng là: -> Một trong những tiêu chí của sản phẩm được kỳ vọng được phân loại theo yếu tố mở rộng là:
# d1e8396b265c4a9791850124001f3c90: Câu 136: Con đường đông máu nội sinh được khởi động bởi yếu tố đông máu: -> Con đường đông máu nội sinh được khởi động bởi yếu tố đông máu:
# d1e8396b265c4a9791850124001f3c90: ['a. Yếu tố III', 'b. Yếu tố VII', 'c. Yếu tố XII', 'd. Yếu tố XIII'] -> ['Yếu tố III', 'Yếu tố VII', 'Yếu tố XII', 'Yếu tố XIII']
# 3c5334a9daf3422599fe97988928257c: Câu 138. Cấp độ thứ ba (Sản phẩm hoàn chỉnh) cấu thành nên một đơn vị sản phẩm đối với các dịch vụ đi kèm có thể là: -> Cấp độ thứ ba (Sản phẩm hoàn chỉnh) cấu thành nên một đơn vị sản phẩm đối với các dịch vụ đi kèm có thể là:
# bc6fa2539c5f4337b66537aec09655bc: Câu 14: Chọn vị thuốc thường dùng để trị chứng phong thấp xảy ra nửa người dưới -> Chọn vị thuốc thường dùng để trị chứng phong thấp xảy ra nửa người dưới
# e3e9fda1d98745afacdc25965cfd7fa7: Câu 14: Dụng cụ được sử dụng trong thăm khám độ sâu túi lợi là -> Dụng cụ được sử dụng trong thăm khám độ sâu túi lợi là
# 9b771bd6e8774ec7a8852f721e2d063a: Câu 14: Sản phẩm khử carboxyl của acid amin sẽ là:
# 1. Acid a cetonic
# 2. Amin tương ứng
# 3. NH3
# 4. Một số chất có hoạt tính sinh học đặc biệt
# 5. Aldehyd
# Chọn tập hợp đúng: -> Sản phẩm khử carboxyl của acid amin sẽ là:
# 1. Acid a cetonic
# 2. Amin tương ứng
# 3. NH3
# 4. Một số chất có hoạt tính sinh học đặc biệt
# 5. Aldehyd
# Chọn tập hợp đúng:
# 8d05e969198a42dbb7722e94cecc4dd9: Câu 14: Theo Quyết định số 2088/BYT-QĐ ngày 06/11/1996 của Bộ Y tế về việc ban hành Quy định về Y đức,tiêu chuẩn nào không phải là tiêu chuẩn đạo đức của người làm công tác y tế? -> Theo Quyết định số 2088/BYT-QĐ ngày 06/11/1996 của Bộ Y tế về việc ban hành Quy định về Y đức,tiêu chuẩn nào không phải là tiêu chuẩn đạo đức của người làm công tác y tế?
# 17d13c022e8845c08693807d5bd6b3c6: Câu 14. Trong công thức thuốc bột, nếu lượng cồn thuốc nhiều quá ta nên khắc phục bằng cách? -> Trong công thức thuốc bột, nếu lượng cồn thuốc nhiều quá ta nên khắc phục bằng cách?
# 19374455d07c4082b7f0773f347c5b10: Câu 1409: Một người phụ nữ có chu kỳ kinh nguyệt không đều (dài hoặc ngắn hơn bình thường) thì rụng trứng có thể xảy ra vào ngày. Chọn câu đúng nhất: -> Một người phụ nữ có chu kỳ kinh nguyệt không đều (dài hoặc ngắn hơn bình thường) thì rụng trứng có thể xảy ra vào ngày. Chọn câu đúng nhất:
# 19374455d07c4082b7f0773f347c5b10: ['A) 14-16 ngày sau khi sạch kinh', 'B) Giữa chu kỳ kinh', 'C) Khoảng 14 ngày trước kỳ kinh tới', 'D) Không thể xác định được khoảng thời gian xảy ra rụng trứng'] -> ['14-16 ngày sau khi sạch kinh', 'Giữa chu kỳ kinh', 'Khoảng 14 ngày trước kỳ kinh tới', 'Không thể xác định được khoảng thời gian xảy ra rụng trứng']
# e0b5e5913ea24e43b8ed8493029ffbcb: Câu 143. Phế âm hư ho ra máu? -> Phế âm hư ho ra máu?
# e3f9a1ca77a24c8798e45cc4c47797a2: Câu 15. Điều trị viêm da cơ địa gồm có -> Điều trị viêm da cơ địa gồm có
# e3f9a1ca77a24c8798e45cc4c47797a2: ['A. Chống ngứa (1)', 'B. Chống nhiễm khuẩn (2)', 'C. Chống khô da (3)', 'D. Cả 3'] -> ['Chống ngứa (1)', 'Chống nhiễm khuẩn (2)', 'Chống khô da (3)', 'Cả 3']
# 943f0543b22a4a9cb26ee4e2ed397cbf: Câu 15. Sedoheptulose gặp ở? -> Sedoheptulose gặp ở?
# 90a6c165c7434b179ab69da9df1ae2b2: Câu 16: Các hình ảnh: loãng xương vùng cạnh khớp,hẹp khe khớp ở các khớp nhỏ,ổ khuyết Xương dưới sụn,hình ảnh bàn tay gió thổi hay lưng lạc đà là biểu hiện của bệnh: -> Các hình ảnh: loãng xương vùng cạnh khớp,hẹp khe khớp ở các khớp nhỏ,ổ khuyết Xương dưới sụn,hình ảnh bàn tay gió thổi hay lưng lạc đà là biểu hiện của bệnh:
# 90a6c165c7434b179ab69da9df1ae2b2: ['A. Viêm cột sống dính khớp.', 'B. Viêm khớp do nhiễm trùng.', 'C. Viêm khớp cấp.', 'D. Viêm khớp dạng thấp.'] -> ['Viêm cột sống dính khớp.', 'Viêm khớp do nhiễm trùng.', 'Viêm khớp cấp.', 'Viêm khớp dạng thấp.']
# 0861d6b0ae2445ebb031a657510da468: Câu 16: Hormon vỏ thượng thận thuộc nhóm: -> Hormon vỏ thượng thận thuộc nhóm:
# 0861d6b0ae2445ebb031a657510da468: ['A. Glucid', 'B. Amin', 'C. Peptid', 'D. Steroid'] -> ['Glucid', 'Amin', 'Peptid', 'Steroid']
# 47d634aa8d174818b856b097d7de5b97: Câu 16. Tên đúng của bệnh viêm da cơ địa là -> Tên đúng của bệnh viêm da cơ địa là
# 47d634aa8d174818b856b097d7de5b97: ['A. Atopic dermatitis', 'B. Contact dermatitis', 'C. Mycosis', 'D. Scabies'] -> ['Atopic dermatitis', 'Contact dermatitis', 'Mycosis', 'Scabies']
# cce264cbcb674ef4af9713d2b309b70e: Câu 161. Mạch phù chủ bệnh ở? -> Mạch phù chủ bệnh ở?
# c58f623822af4a078d354161ab9e750b: Câu 163: Để trị băng huyết, a giao nên sao với gì? -> Để trị băng huyết, a giao nên sao với gì?
# 7669be0762df4f6b898573388b61820c: Câu 17: Đối với bệnh thấp tim, chẩn đoán tổn thương tim dựa vào các xét nghiệm: -> Đối với bệnh thấp tim, chẩn đoán tổn thương tim dựa vào các xét nghiệm:
# 6a7fdc7d2e744ef894404a7a598e2b14: Câu 17: Thứ nào sau đây nằm trong ti thể? -> Thứ nào sau đây nằm trong ti thể?
# 6a7fdc7d2e744ef894404a7a598e2b14: ['A. Cytochrome oxidase', 'B. Succinate dehydrogenase', 'C. Dihydrolipoyl dehydrogenase', 'D. Tất cả những thứ trên'] -> ['Cytochrome oxidase', 'Succinate dehydrogenase', 'Dihydrolipoyl dehydrogenase', 'Tất cả những thứ trên']
# 1efc3c5c31e24d6b97ab1afc538ee868: Câu 17. trong bài Thiên hoa phấn, vị thuốc có tác dụng ích khí điều hòa các vị thuốc(ĐTĐ TT) -> trong bài Thiên hoa phấn, vị thuốc có tác dụng ích khí điều hòa các vị thuốc(ĐTĐ TT)
# 16d6fe3f2aba4335b694f800326fc01d: Câu 170. Ở giai đoạn sớm, quyết định sự phát triển của phôi người thành nam giới là gen: -> Ở giai đoạn sớm, quyết định sự phát triển của phôi người thành nam giới là gen:
# 16d6fe3f2aba4335b694f800326fc01d: ['A. TDF', 'B. SRY', 'C. DAX1', 'D. ZFY'] -> ['TDF', 'SRY', 'DAX1', 'ZFY']
# a2d845d8abbf46df9a10b91d66a984bb: Câu 171. Xác định sự phát triển của buồng trứng nhờ gen: -> Xác định sự phát triển của buồng trứng nhờ gen:
# a2d845d8abbf46df9a10b91d66a984bb: ['A. DAX1, SRY', 'B. SRY, ZFY', 'C. DAX1, WNT4', 'D. WNT4, ZFY'] -> ['DAX1, SRY', 'SRY, ZFY', 'DAX1, WNT4', 'WNT4, ZFY']
# 8f69260285e1470ea3f9f8297305963a: Câu 172. Tất cả cơ quan sinh dục đều phải trải qua mấy giai đoạn biệt hoá? -> Tất cả cơ quan sinh dục đều phải trải qua mấy giai đoạn biệt hoá?
# 8f69260285e1470ea3f9f8297305963a: ['A. 2', 'B. 3', 'C. 4', 'D. 5'] -> ['2', '3', '4', '5']
# 244e9a814b57474db479baa5f09739a2: Câu 173: Vết bầm máu có màu xanh lá mạ, ước đoán thời gian bị chấn thương là: -> Vết bầm máu có màu xanh lá mạ, ước đoán thời gian bị chấn thương là:
# b7b9a392f5bf4b849cf6b0d36e795ef2: Câu 173. Giai đoạn về hình dáng và cấu tạo không phân biệt được nam hay nữ là giai đoạn trung tính (chưa biệt hoá)? -> Giai đoạn về hình dáng và cấu tạo không phân biệt được nam hay nữ là giai đoạn trung tính (chưa biệt hoá)?
# b7b9a392f5bf4b849cf6b0d36e795ef2: ['A. Đ', 'B. S'] -> ['Đ', 'S']
# c056db966ba04d1185a6aba65c64a615: Câu 174. Khí hư hay gặp ở người già mắc bệnh nặng lâu ngày? -> Khí hư hay gặp ở người già mắc bệnh nặng lâu ngày?
# 38fd9391d0a74707b3098fff4690aa99: Câu 174. Sự kiện đầu tiên và quan trọng nhất quyết định biệt hoá tuyến sinh dục nam, nữ? -> Sự kiện đầu tiên và quan trọng nhất quyết định biệt hoá tuyến sinh dục nam, nữ?
# 38fd9391d0a74707b3098fff4690aa99: ['A. TB sinh dục nguyên thuỷ có mặt ở mào sinh dục vào cuối tuần thứ 3 (ngày 21) ở thành sau túi noãn hoàng, gần niệu nang', 'B. TB sinh dục nguyên thuỷ di cư đến trung bì trung gian vào tuần thứ 4 ở bên trong trung thận để tạo mầm tuyến sinh dục', 'C. Dây sinh dục nguyên phát dài ra vào tuần thứ 6 thành dây sinh dục tuỷ', 'D. Dây sinh dục tuỷ tiến vào trung tâm tuyến sinh dục vào tuần thứ 7'] -> ['TB sinh dục nguyên thuỷ có mặt ở mào sinh dục vào cuối tuần thứ 3 (ngày 21) ở thành sau túi noãn hoàng, gần niệu nang', 'TB sinh dục nguyên thuỷ di cư đến trung bì trung gian vào tuần thứ 4 ở bên trong trung thận để tạo mầm tuyến sinh dục', 'Dây sinh dục nguyên phát dài ra vào tuần thứ 6 thành dây sinh dục tuỷ', 'Dây sinh dục tuỷ tiến vào trung tâm tuyến sinh dục vào tuần thứ 7']
# e8134a376ee346f7983cc35e28ea4830: Câu 175. Mạch đi lại lưu lợi, trơn như hòn bi lăn trong đĩa? -> Mạch đi lại lưu lợi, trơn như hòn bi lăn trong đĩa?
# 6f41fc7c03e74e3f90c6dba50646706e: Câu 175. TB sinh dục nguyên thuỷ di cư đến trung bì trung gian ở bên trong trung thận để tạo mầm tuyến sinh dục vào tuần: -> TB sinh dục nguyên thuỷ di cư đến trung bì trung gian ở bên trong trung thận để tạo mầm tuyến sinh dục vào tuần:
# 6f41fc7c03e74e3f90c6dba50646706e: ['A. 3', 'B. 4', 'C. 6', 'D. 7'] -> ['3', '4', '6', '7']
# 673e76afe40c4f21bcbc6a20abe672ad: Câu 176. Dây sinh dục nguyên phát dài ra thành dây sinh dục tuỷ vào tuần: -> Dây sinh dục nguyên phát dài ra thành dây sinh dục tuỷ vào tuần:
# 673e76afe40c4f21bcbc6a20abe672ad: ['A. 3', 'B. 4', 'C. 6', 'D. 7'] -> ['3', '4', '6', '7']
# 406f88622bf949f5809e90b1dc7d66a1: Câu 177. Dây sinh dục tuỷ tiến vào trung tâm tuyến sinh dục thành dây tinh hoàn vào tuần: -> Dây sinh dục tuỷ tiến vào trung tâm tuyến sinh dục thành dây tinh hoàn vào tuần:
# 406f88622bf949f5809e90b1dc7d66a1: ['A. 3', 'B. 4', 'C. 6', 'D. 7'] -> ['3', '4', '6', '7']
# 39e3878a3da340a0be8f755c6fe04b2a: Câu 178. Thoạt tiên tuyến sinh dục trung tính cùng với trung thận tạo thành 1 khối lồi vào khoang cơ thể gọi là: -> Thoạt tiên tuyến sinh dục trung tính cùng với trung thận tạo thành 1 khối lồi vào khoang cơ thể gọi là:
# 39e3878a3da340a0be8f755c6fe04b2a: ['A. Mào sinh dục', 'B. Mào niệu-sinh dục', 'C. Dây sinh dục tuỷ', 'D. Dây tinh hoàn'] -> ['Mào sinh dục', 'Mào niệu-sinh dục', 'Dây sinh dục tuỷ', 'Dây tinh hoàn']
# 098e479714714e989bacbeae7c526cfd: Câu 179. Về sau, tuyến sinh dục trung tính lồi lên hẳn mặt thành sau của khoang cơ thể, phía trước trung thận, tạo thành một mào riêng gọi là: -> Về sau, tuyến sinh dục trung tính lồi lên hẳn mặt thành sau của khoang cơ thể, phía trước trung thận, tạo thành một mào riêng gọi là:
# 098e479714714e989bacbeae7c526cfd: ['A. Mào sinh dục', 'B. Mào niệu-sinh dục', 'C. Dây sinh dục tuỷ', 'D. Dây tinh hoàn'] -> ['Mào sinh dục', 'Mào niệu-sinh dục', 'Dây sinh dục tuỷ', 'Dây tinh hoàn']
# 52a9013e02474a6b92973aef4c7794bd: Câu 18 Phản xạ ức chế do : -> Phản xạ ức chế do :
# 52a9013e02474a6b92973aef4c7794bd: ['A.Kt Lạnh đột ngột vào vùn thành sau họng', 'B.Kt Lạnh đột ngột vào cổ, ngực', 'C.Kt Lạnh đột ngột vào vùng thanh quản', 'D. cả ba'] -> ['Kt Lạnh đột ngột vào vùn thành sau họng', 'Kt Lạnh đột ngột vào cổ, ngực', 'Kt Lạnh đột ngột vào vùng thanh quản', 'cả ba']
# dbf68912cdf54ecba26501dde78daa01: câu 18: theo WHO 2013, chỉ định chiếu đèn khi (Tiếng Việt) -> theo WHO 2013, chỉ định chiếu đèn khi (Tiếng Việt)
# 65411a8b480b475fa90c3138c5b33acf: Câu 18: Trong bệnh dị ứng thuốc dạng viêm thành mạch dị ứng, tổn thương điển hình của bệnh là gì? -> Trong bệnh dị ứng thuốc dạng viêm thành mạch dị ứng, tổn thương điển hình của bệnh là gì?
# 2819741d151e428393e3ec58142498ba: Câu 18. Hội chứng DRESS là: -> Hội chứng DRESS là:
# 36fbdcaa01f9444e9a49be1c3363c7d0: Câu 180. Có bao nhiêu tiểu thuỳ ở tuần thứ 7 của phôi? -> Có bao nhiêu tiểu thuỳ ở tuần thứ 7 của phôi?
# 36fbdcaa01f9444e9a49be1c3363c7d0: ['A. 50', 'B. 100', 'C. 150', 'D. 200'] -> ['50', '100', '150', '200']
# 4e19c2edb64d4d62a4336c0d9caacc4e: Câu 181. Bệnh Hodgkin thể hỗn hợp TB là type -> Bệnh Hodgkin thể hỗn hợp TB là type
# 941c8662d4164e78a66a1f79e19ee9b0: Câu 181. Mỗi dây tinh hoàn sẽ phân thành mấy dây nhỏ hơn mà sau này sẽ thành ống sinh tinh? -> Mỗi dây tinh hoàn sẽ phân thành mấy dây nhỏ hơn mà sau này sẽ thành ống sinh tinh?
# 941c8662d4164e78a66a1f79e19ee9b0: ['A. 1-2', 'B. 2-3', 'C. 3-4', 'D. 4-5'] -> ['1-2', '2-3', '3-4', '4-5']
# 3230e91212c849548bef729877ba45cb: Câu 182. Ống sinh tinh đặc đến tháng thứ mấy thai nhi? -> Ống sinh tinh đặc đến tháng thứ mấy thai nhi?
# 3230e91212c849548bef729877ba45cb: ['A. 4', 'B. 5', 'C. 6', 'D. 7'] -> ['4', '5', '6', '7']
# ae572df1a2a24fc4a9c616585c84621e: Câu 182. Viêm da hạt do Candida hay gặp ở? -> Viêm da hạt do Candida hay gặp ở?
# f2985785149846758d1a09d16092079b: Câu 183. TB biểu mô nằm trong các dây tinh hoàn vây quanh các tinh nguyên bào sẽ biệt hoá thành TB Sertoli? -> TB biểu mô nằm trong các dây tinh hoàn vây quanh các tinh nguyên bào sẽ biệt hoá thành TB Sertoli?
# f2985785149846758d1a09d16092079b: ['A. Đ', 'B. S'] -> ['Đ', 'S']
# 10a2e0f852ca46ef9444e96a4af42816: Câu 184. TB biểu mô nằm trong các dây sinh dục tuỷ sẽ biệt hoá thành TB Sertoli từ tuần: -> TB biểu mô nằm trong các dây sinh dục tuỷ sẽ biệt hoá thành TB Sertoli từ tuần:
# 10a2e0f852ca46ef9444e96a4af42816: ['A. 3', 'B. 4', 'C. 6', 'D. 7'] -> ['3', '4', '6', '7']
# c1ba3e39859647ab90d0d6807c786d14: Câu 185. TB biểu mô nằm trong các dây sinh dục tuỷ sẽ biệt hoá thành TB Sertoli do mang gen: -> TB biểu mô nằm trong các dây sinh dục tuỷ sẽ biệt hoá thành TB Sertoli do mang gen:
# c1ba3e39859647ab90d0d6807c786d14: ['A. DAX1', 'B. ZFY', 'C. SRY', 'D. TDF'] -> ['DAX1', 'ZFY', 'SRY', 'TDF']
# a0f376f59edf409d80648a18215b45ba: Câu 186. Ở nam, quá trình phân chia, giảm phân không xảy ra cho đến tuổi dậy thì là do TB Sertoli? -> Ở nam, quá trình phân chia, giảm phân không xảy ra cho đến tuổi dậy thì là do TB Sertoli?
# a0f376f59edf409d80648a18215b45ba: ['A. Đ', 'B. S'] -> ['Đ', 'S']
# 3b0f505bba104886a84b46cf3277fdf8: Câu 187. TB tiền Sertoli bài tiết ra: -> TB tiền Sertoli bài tiết ra:
# 3b0f505bba104886a84b46cf3277fdf8: ['A. Hormon kháng ống cận trung thận AMH', 'B. Chất ức chế ống cận trung thận MIS', 'C. Hormon hướng sinh dục của màng đệm', 'D. A và B đúng'] -> ['Hormon kháng ống cận trung thận AMH', 'Chất ức chế ống cận trung thận MIS', 'Hormon hướng sinh dục của màng đệm', 'A và B đúng']
# 37fc5495d14045fe9a48605822bad01b: Câu 188. Trong giai đoạn sớm thì quá trình bài tiết hormon của TB kẽ chịu sự điều hoà của hormon peptid là: -> Trong giai đoạn sớm thì quá trình bài tiết hormon của TB kẽ chịu sự điều hoà của hormon peptid là:
# 37fc5495d14045fe9a48605822bad01b: ['A. Hormon kháng ống cận trung thận AMH', 'B. Chất ức chế ống cận trung thận MIS', 'C. Hormon hướng sinh dục của màng đệm', 'D. A và B đúng'] -> ['Hormon kháng ống cận trung thận AMH', 'Chất ức chế ống cận trung thận MIS', 'Hormon hướng sinh dục của màng đệm', 'A và B đúng']
# de669ffebe194b5eba9ebedbd1a59e22: Câu 189. Biguanid dễ gây toan do làm tăng acid lactic -> Biguanid dễ gây toan do làm tăng acid lactic
# 464e3c764e954655bf97b0ce55eef14e: Câu 189. TB biểu mô nằm trong các dây sinh dục tuỷ sẽ biệt hoá thành TB ……… do không mang gen SRY: -> TB biểu mô nằm trong các dây sinh dục tuỷ sẽ biệt hoá thành TB ……… do không mang gen SRY:
# 464e3c764e954655bf97b0ce55eef14e: ['A. TB Leydig', 'B. TB Sertoli', 'C. Tb nang', 'D. TB noãn'] -> ['TB Leydig', 'TB Sertoli', 'Tb nang', 'TB noãn']
# f22a462baa6147e3bc4dc32aeb06c198: Câu 19: Đối với bệnh thấp tim, chẩn đoán viêm không đặc hiệu dựa vào các xét nghiệm -> Đối với bệnh thấp tim, chẩn đoán viêm không đặc hiệu dựa vào các xét nghiệm
# e28bfab046cf40aa8947066a287e7f26: Câu 19: Phân tử nào là phân tử đồng kích thích trên APC? -> Phân tử nào là phân tử đồng kích thích trên APC?
# 6a5d2158a796403e8db2bc7b76ff119e: Câu 19. Đặc điểm săng giang mai giai đoạn 1? -> Đặc điểm săng giang mai giai đoạn 1?
# 204ca4469eb64566a7cffc3b1f5c128d: Câu 19. Tỷ lệ phát hiện ASLO (Anti-Streptolysin O) dương tính trong thấp khớp cấp là bao nhiêu? -> Tỷ lệ phát hiện ASLO (Anti-Streptolysin O) dương tính trong thấp khớp cấp là bao nhiêu?
# 86316e06920e4e9ea6478c69d1ecab87: Câu 190: Dị tật nội tạng như thận hình móng ngựa, ứ nước...là biểu hiện của hội chứng nào? (Dịch: Nội tạng dị tật như thận móng ngựa, tích nước...là biểu hiện của hội chứng nào?) -> Dị tật nội tạng như thận hình móng ngựa, ứ nước...là biểu hiện của hội chứng nào? (Dịch: Nội tạng dị tật như thận móng ngựa, tích nước...là biểu hiện của hội chứng nào?)
# 86316e06920e4e9ea6478c69d1ecab87: ['A. Down', 'B. Siêu nam (Siêu nam)', 'C. Turner', 'D. Klinerfeler'] -> ['Down', 'Siêu nam (Siêu nam)', 'Turner', 'Klinerfeler']
# 81c06bdb19564c6bb50f1fd2b928cc82: Câu 190. Mào sinh dục biệt hoá thành buồng trứng vào: -> Mào sinh dục biệt hoá thành buồng trứng vào:
# 81c06bdb19564c6bb50f1fd2b928cc82: ['A. Cuối tuần 8', 'B. Đầu tuần 9', 'C. Đầu tuần 8', 'D. Cuối tuần 9'] -> ['Cuối tuần 8', 'Đầu tuần 9', 'Đầu tuần 8', 'Cuối tuần 9']
# b75db6b6f19643cc8c373d769852c082: Câu 191. Sự ngừng hoạt động của 1 trong 2 NST X trong TB soma 46, XX xảy ra ở giai đoạn muộn của quá trình phát triển phôi? -> Sự ngừng hoạt động của 1 trong 2 NST X trong TB soma 46, XX xảy ra ở giai đoạn muộn của quá trình phát triển phôi?
# b75db6b6f19643cc8c373d769852c082: ['A. Đ', 'B. S'] -> ['Đ', 'S']
# adbabbc9c16241c6bc6ba9fcd2c9ce0c: Câu 192. Trong các TB noãn, cả 2 NST giới tính XX vẫn hoạt động? -> Trong các TB noãn, cả 2 NST giới tính XX vẫn hoạt động?
# adbabbc9c16241c6bc6ba9fcd2c9ce0c: ['A. Đ', 'B. S'] -> ['Đ', 'S']
# 6ec078f6da894516866d0aab8eb7619c: Câu 193. Mạch kết là mạch? -> Mạch kết là mạch?
# 017ce04d9c60456d8ec99fb6cef8f6e4: Câu 193. Testosterol kích thích ống trung thận dọc biệt hoá và phát triển thành: -> Testosterol kích thích ống trung thận dọc biệt hoá và phát triển thành:
# 017ce04d9c60456d8ec99fb6cef8f6e4: ['A. Tuyến phụ thuộc niệu đạo', 'B. Cơ quan sinh dục ngoài của nam', 'C. Đường dẫn tinh', 'D. A và B đúng'] -> ['Tuyến phụ thuộc niệu đạo', 'Cơ quan sinh dục ngoài của nam', 'Đường dẫn tinh', 'A và B đúng']
# e93238ebb09f46169b6e608ee54506fb: Câu 194. Lòng ống sinh tinh xuất hiện khi: -> Lòng ống sinh tinh xuất hiện khi:
# e93238ebb09f46169b6e608ee54506fb: ['A. Bào thai', 'B. Sơ sinh', 'C. Dậy thì', 'D. Sau dậy thì'] -> ['Bào thai', 'Sơ sinh', 'Dậy thì', 'Sau dậy thì']
# ba8bffe0eeeb44dabc1a14a52be45cfd: Câu 195: Miễn dịch chống bệnh sởi do mẹ truyền cho con trong những tháng đầu sau khi sinh gọi là miễn dịch: -> Miễn dịch chống bệnh sởi do mẹ truyền cho con trong những tháng đầu sau khi sinh gọi là miễn dịch:
# 8bff7eea37314add86814ab582b8cdb4: Câu 2: Chỉ định chuyển ICU của đợt cấp COPD -> Chỉ định chuyển ICU của đợt cấp COPD
# 608b4912c7db4062936cf84113835e98: Câu 2: Lớp áo ngoài của tĩnh mạch có đặc điểm: -> Lớp áo ngoài của tĩnh mạch có đặc điểm:
# 42ac77f4b88a40a9ad8ac0794b76ac02: Câu 2: Môi trường sống của loài sán lá gan ở trong ống tiêu hóa của loài trâu, bò, lợn,...là gì? -> Môi trường sống của loài sán lá gan ở trong ống tiêu hóa của loài trâu, bò, lợn,...là gì?
# a4dc74d82df945ac8e80e237e136d4cd: Câu 2: Trong các nhóm protein sau, loại nào có cấu tạo là protein tạp -> Trong các nhóm protein sau, loại nào có cấu tạo là protein tạp
# b7f635d3e42c40acb499393f9058f686: câu 2. thực hiện tầm soát bệnh võng mạc trẻ đẻ non (Tiếng Việt) -> thực hiện tầm soát bệnh võng mạc trẻ đẻ non (Tiếng Việt)
# b7f635d3e42c40acb499393f9058f686: ['a. trẻ <1500g hoặc đẻ non <29w (Tiếng Việt)', 'b. trẻ 1500-2000g (Tiếng Việt)', 'c. trẻ <1500g hoặc đẻ non < 32w (Tiếng Việt)', 'd. trẻ <1500-2000g hoặc đẻ non <29w (Tiếng Việt)'] -> ['trẻ <1500g hoặc đẻ non <29w (Tiếng Việt)', 'trẻ 1500-2000g (Tiếng Việt)', 'trẻ <1500g hoặc đẻ non < 32w (Tiếng Việt)', 'trẻ <1500-2000g hoặc đẻ non <29w (Tiếng Việt)']
# 015baaf12f8645e9b3933b6f7856bdd3: Câu 20: Cấu tạo tinh bột và glycogen giống nhau ở chỗ: -> Cấu tạo tinh bột và glycogen giống nhau ở chỗ:
# a464f4ff061f4281b4c3cce735fe7da3: Câu 20: Dẫn truyền xung động thần kinh ở sợi có myelinnhanh hơn sợi không myelin là do: -> Dẫn truyền xung động thần kinh ở sợi có myelinnhanh hơn sợi không myelin là do:
# c58ccd0f66ff4380a6766b6434180317: Câu 20: Đặc điểm nào đúng đối với bệnh loãng xương người già? -> Đặc điểm nào đúng đối với bệnh loãng xương người già?
# 6b9114e3cbea44d3a028381e7408ff77: Câu 20. Mật độ phân tử khí được tính theo công thức: -> Mật độ phân tử khí được tính theo công thức:
# 3db8a74f2e9c4ce79b61b9494ec30c88: Câu 207. VKDT có kiểu diễn biến -> VKDT có kiểu diễn biến
# 0f5536d590d94e4cb8ba4f3b2696fde5: Câu 21: Các acid amin sau tham gia vào quá trình tạo Creatinin: -> Các acid amin sau tham gia vào quá trình tạo Creatinin:
# d9f6002863d1476f9a8890a0f6ccc0df: Câu 21: Hormon sinh dục nữ được tạo thành do: -> Hormon sinh dục nữ được tạo thành do:
# 835175a1f7f44e068c8b94b475ebd346: Câu 21. Cấu trúc bậc 2 của protein là: -> Cấu trúc bậc 2 của protein là:
# d9004a24ab4f47928997934570e79114: Câu 21. Đặc điểm vỏ của vi khuẩn: -> Đặc điểm vỏ của vi khuẩn:
# 9c7219242b2549eca761ee0801e7107c: Câu 2152: Nguyên nhân không gây ra chửa ngoài tử cung: -> Nguyên nhân không gây ra chửa ngoài tử cung:
# e90b88a4a0954f97859c76e7ffd27352: Câu 219. HA phản ánh hoạt động thực sự của tim: -> HA phản ánh hoạt động thực sự của tim:
# dec4df90c1e64ee4bd6fe524d25bb78d: Câu 22: Để đẩy mạnh tác dụng của thuốc phát thanh phong thấp cần phối hợp với nhóm thuốc nào sau đây -> Để đẩy mạnh tác dụng của thuốc phát thanh phong thấp cần phối hợp với nhóm thuốc nào sau đây
# bfeb43a43c3d4e7f88b5e45b39b1cabc: Câu 22. Căn nguyên gây hồng ban da dạng là -> Căn nguyên gây hồng ban da dạng là
# bfeb43a43c3d4e7f88b5e45b39b1cabc: ['A. Do thuốc', 'B. Do chấn thương', 'C. Do phẫu thuật', 'D. Do vận động mạnh'] -> ['Do thuốc', 'Do chấn thương', 'Do phẫu thuật', 'Do vận động mạnh']
# 60d5f2f1e6b9458dbe5c3bf07122f0b4: Câu 226. Theo Đào Hoàng Cảnh bào chế Hạnh nhân bằng phương pháp nào? -> Theo Đào Hoàng Cảnh bào chế Hạnh nhân bằng phương pháp nào?
# f92fdf81c6b644ccad5aaa1218bfc182: Câu 23. Biến chứng nào có thể xảy ra của viêm cầu thận cấp? -> Biến chứng nào có thể xảy ra của viêm cầu thận cấp?
# f92fdf81c6b644ccad5aaa1218bfc182: ['a. Suy tim cấp, viêm cầu thận mạn tính, suy thận', 'b. Xơ gan, nhồi máu cơ tim, viêm vi cầu thận cấp', 'c. Suy thận, hội chứng thận hư, hoại tử cơ tim', 'd. Suy tủy, tiểu dưỡng chấp, viêm đường tiết niệu – sinh dục'] -> ['Suy tim cấp, viêm cầu thận mạn tính, suy thận', 'Xơ gan, nhồi máu cơ tim, viêm vi cầu thận cấp', 'Suy thận, hội chứng thận hư, hoại tử cơ tim', 'Suy tủy, tiểu dưỡng chấp, viêm đường tiết niệu – sinh dục']
# 1f30194e07e24b47a00cb8e27beb5199: Câu 230. Suy giảm Testosterol bắt đầu khi nào? -> Suy giảm Testosterol bắt đầu khi nào?
# bb07ceb6300a4a0da4621531b120f5a7: Câu 24. Yêu cầu của thuốc Generic là: -> Yêu cầu của thuốc Generic là:
# 452ac9390e76422da321d09a72e072f5: Câu 248: Trong ngạt nước, hiện tượng xà phòng hoá tử thi xuất hiện trong khoảng thời gian. -> Trong ngạt nước, hiện tượng xà phòng hoá tử thi xuất hiện trong khoảng thời gian.
# b74ab247f3864f5d9bac6706d4181629: Câu 249. Xuyên khung bộ phận dùng là gì? -> Xuyên khung bộ phận dùng là gì?
# b74ab247f3864f5d9bac6706d4181629: ['A. Rễ', 'B. Thân rễ', 'C. Cành', 'D. Quả'] -> ['Rễ', 'Thân rễ', 'Cành', 'Quả']
# c0e8145a97c549ada1c0564e505f38a4: Câu 25: Thuốc bổ âm không dùng cho người tỳ vị hư hàn đầy chướng bụng đi ỉa chảy? -> Thuốc bổ âm không dùng cho người tỳ vị hư hàn đầy chướng bụng đi ỉa chảy?
# 40290e2bd9d2435993dd39a98009d213: Câu 25: Trình độ của người quản lý thuốc phóng xạ: phải là dược sỹ trung học trở lên hoặc bác sỹ, kỹ thuật viên, điều dưỡng viên (được đào tạo về an toàn bức xạ)? -> Trình độ của người quản lý thuốc phóng xạ: phải là dược sỹ trung học trở lên hoặc bác sỹ, kỹ thuật viên, điều dưỡng viên (được đào tạo về an toàn bức xạ)?
# f4d5594570d4436d861366caf2356326: Câu 25. Đau cơ khu trú ở một cơ thường là do nguyên nhân gì? -> Đau cơ khu trú ở một cơ thường là do nguyên nhân gì?
# e3b7e88c00f24eb2af955bdba3d6d18d: Câu 26: Cơ chế gây tiêu chảy của Đại hoàng là gì? -> Cơ chế gây tiêu chảy của Đại hoàng là gì?
# 030a885d7dbe48dea96d62ed92a34a87: Câu 26. Mục tiêu sử dụng Adrenalin và dịch truyền nhằm nâng, duy trì ổn định huyết áp tối đa của người lớn lên: -> Mục tiêu sử dụng Adrenalin và dịch truyền nhằm nâng, duy trì ổn định huyết áp tối đa của người lớn lên:
# bd3f3475d63b41dfb05e1012aa67c935: Câu 261: Đối với hầu hết các bệnh truyền từ động vật sang người thì: -> Đối với hầu hết các bệnh truyền từ động vật sang người thì:
# 8880aa99fdfe490db049024625d84a6f: Câu 27: Năm 1894 Alexande Yersin đã phát hiện ra loại vi khuẩn gì? -> Năm 1894 Alexande Yersin đã phát hiện ra loại vi khuẩn gì?
# 1fa79f69655b4a81994385bf3e345751: Câu 27: Sterol là một nhóm của những chất -> Sterol là một nhóm của những chất
# 83c7faab3a054b86b9e78c559688f877: Câu 27. Chống chỉ định tuyệt đối dùng tiêu huyết khối ở BN (bệnh nhân) nhồi máu não? -> Chống chỉ định tuyệt đối dùng tiêu huyết khối ở BN (bệnh nhân) nhồi máu não?
# 39ba5df045d541ee86794d7ae7950bf8: Câu 27. Vai trò của tá dược THUỐC MỠ KHÔNG bao gồm yếu tố nào sau đây? -> Vai trò của tá dược THUỐC MỠ KHÔNG bao gồm yếu tố nào sau đây?
# 96de4fdc35ca4c5083a59ab13a34b83a: Câu 28: Một cháu bé bị chàm cữa mũi do viêm VA mạn tính. Cách điều trị nào sau đây là quan trọng nhất: -> Một cháu bé bị chàm cữa mũi do viêm VA mạn tính. Cách điều trị nào sau đây là quan trọng nhất:
# 190ddca7e9e644928c7628ce2c7eb8b7: Câu 28: Những acid amin sau được xếp vào nhóm acid amin kiềm: -> Những acid amin sau được xếp vào nhóm acid amin kiềm:
# 067421a6ac5e4ee5bd02697a165691f6: Câu 287,. Bệnh nguyên học không nghiên cứu về: -> Bệnh nguyên học không nghiên cứu về:
# b53271f3abcf4e7a97df3f30c6958277: Câu 292: Biện pháp tác động vào nguồn lây để phòng chống bệnh dại là: -> Biện pháp tác động vào nguồn lây để phòng chống bệnh dại là:
# 88683c6d23434af7b03b5c60d940667a: Câu 293: Biện pháp để phòng bệnh lây qua da, niêm mạc do súc vật truyền sang người không phù hợp là: -> Biện pháp để phòng bệnh lây qua da, niêm mạc do súc vật truyền sang người không phù hợp là:
# bfc78c352c3c4ce0bc925809eab4dc60: Câu 297: Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
# a Một số bệnh sau khi khỏi bệnh không có miễn dịch lâu bền như bệnh than, lở mồm long móng.
# b Bệnh lây qua da, niêm mạc có phương thức lây trực tiếp là bệnh: Lở mồm long móng
# c Để có thể hình thành giả thuyết nhân quả phải tiến hành nghiên cứu: Phân tích
# d Trong nghiên cứu bệnh chứng: OR được gọi là tỷ suất chênh
# e Trong nghiên cứu bệnh chứng:RR phải tính gián tiếp qua OR -> Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
# a Một số bệnh sau khi khỏi bệnh không có miễn dịch lâu bền như bệnh than, lở mồm long móng.
# b Bệnh lây qua da, niêm mạc có phương thức lây trực tiếp là bệnh: Lở mồm long móng
# c Để có thể hình thành giả thuyết nhân quả phải tiến hành nghiên cứu: Phân tích
# d Trong nghiên cứu bệnh chứng: OR được gọi là tỷ suất chênh
# e Trong nghiên cứu bệnh chứng:RR phải tính gián tiếp qua OR
# a70956dd881943728ec9405cabc86a79: Câu 298.Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
# a Tất cả các loài động vật máu nóng đều có thể bị bệnh dại.
# b Động vật chân đốt không phải là yếu tố trung gian truyền nhiễm
# c Tần số tuyệt đối là biểu thị của tần số trong một mối tương quan với cỡ mẫu
# d Tần số: Biểu thị số lần suất hiện của một quan sát nào đó
# e Tỷ số là một phân số, trong đó tử số có thể lkhoong thuộc mẫu số -> Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
# a Tất cả các loài động vật máu nóng đều có thể bị bệnh dại.
# b Động vật chân đốt không phải là yếu tố trung gian truyền nhiễm
# c Tần số tuyệt đối là biểu thị của tần số trong một mối tương quan với cỡ mẫu
# d Tần số: Biểu thị số lần suất hiện của một quan sát nào đó
# e Tỷ số là một phân số, trong đó tử số có thể lkhoong thuộc mẫu số
# bd1a6df040c5404c92668f7aba39ee3e: Câu 299: Những yếu tố nào sau đây không phải là yếu tố trung gian truyền nhiễm: -> Những yếu tố nào sau đây không phải là yếu tố trung gian truyền nhiễm:
# e653dfc82fe9421c91123fc01852efeb: Câu 3: Tế bào hắc tố có các đặc điểm sau, TRỪ MỘT: -> Tế bào hắc tố có các đặc điểm sau, TRỪ MỘT:
# 6d31f4d5839343a28759ae2386f15d93: Câu 3. Bệnh nhân nam 80 tuổi nghề nghiệp giáo viên cấp 3 về hưu, bị bệnh hơn 15 năm nay, hay phát bệnh mùa đông. Đợt 1/2016 vào viện điều trị với các triệu chứng khó thở đột ngột, tiếng rít, khó thở thì thở ra và đã được điều trị ổn định với chẩn đoán tây y là HPQ. Hiện tại bệnh nhân hết triệu chứng thở rít, đỡ khó thở nhiều, tuy nhiên còn nhiều biểu hiện triệu chứng sợ lạnh, sắc mặt trắng bệch, hồi hộp ù tai, hơi thở ngắn. Càng lao động càng tăng, khạc đờm có bọt, lưng gối mỏi yếu, nước tiểu trong dài, tiểu tiện nhiều lần, lưỡi đạm, rêu nhuận, mạch trầm tế vô lực. Bệnh nhân được chẩn đoán theo YHCT? -> Bệnh nhân nam 80 tuổi nghề nghiệp giáo viên cấp 3 về hưu, bị bệnh hơn 15 năm nay, hay phát bệnh mùa đông. Đợt 1/2016 vào viện điều trị với các triệu chứng khó thở đột ngột, tiếng rít, khó thở thì thở ra và đã được điều trị ổn định với chẩn đoán tây y là HPQ. Hiện tại bệnh nhân hết triệu chứng thở rít, đỡ khó thở nhiều, tuy nhiên còn nhiều biểu hiện triệu chứng sợ lạnh, sắc mặt trắng bệch, hồi hộp ù tai, hơi thở ngắn. Càng lao động càng tăng, khạc đờm có bọt, lưng gối mỏi yếu, nước tiểu trong dài, tiểu tiện nhiều lần, lưỡi đạm, rêu nhuận, mạch trầm tế vô lực. Bệnh nhân được chẩn đoán theo YHCT?
# 50f73d5ff5f543efb59dc68a888f1942: Câu 3. Một em bé dưới 1 tuổi đang bị khó thở thanh quản độ 2, không nên: -> Một em bé dưới 1 tuổi đang bị khó thở thanh quản độ 2, không nên:
# 30e7fa1a47b445a7a41fe0ae51481f47: Câu 3. Tăng tỉ lệ gia tăng dân số là do: -> Tăng tỉ lệ gia tăng dân số là do:
# 29945e88bca342d7af8dd5706f69fa35: câu 3. theo biểu đồ Fenton, trẻ SDD khi? (Tiếng Việt) -> theo biểu đồ Fenton, trẻ SDD khi? (Tiếng Việt)
# 5f953fdc5e514e628a6500854141f88b: Câu 30: Đặc điểm của nhân vãi là: -> Đặc điểm của nhân vãi là:
# 8c86703844ee4a1b95338cbe215e7fc8: Câu 30: Những triệu chứng có thể gặp trong ngộ độc digitalis ở trẻ em biểu hiện phổ biến ở cơ quan thị giác: TRỪ -> Những triệu chứng có thể gặp trong ngộ độc digitalis ở trẻ em biểu hiện phổ biến ở cơ quan thị giác: TRỪ
# d61dd6ff934842bcab6f60efc97e10cd: Câu 30: Sterid thuộc loại chât nào: -> Sterid thuộc loại chât nào:
# 89cd4bc259f1451db0edb57393721131: Câu 302: Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
# a Trong dịch tễ học lâm sàng, các nguyên lý và phương pháp DTH được áp dụng chỉ có Đánh giá một trắc nghiệm chẩn đoán, Phân tích các quyết định lâm sàng,Thử nghiệm lâm sàng ngẫu nhiên có đối chứng
# b Nếu các hoạt động dự phòng cấp hai có kết quả thì sẽ làm giảm: Thời gian phát triển trung bình của một bệnh
# c Nếu các hoạt động dự phòng cấp ba có kết quả thì sẽ làm giảm: Tỷ lệ mới mắc
# d Có một tỷ lệ nhỏ sau khi mắc bệnh sởi có thể bị mắc viêm não sơ cứng bán cấp gây rối loạn thần kinh tiến triển
# e Trong dự phòng cấp 1: Các biện pháp bảo vệ đặc hiệu bao gồm việc gây miễn dịch đặc hiệu, vệ sinh môi trường, các biện pháp bảo vệ chống các tai nạn xã hội… -> Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
# a Trong dịch tễ học lâm sàng, các nguyên lý và phương pháp DTH được áp dụng chỉ có Đánh giá một trắc nghiệm chẩn đoán, Phân tích các quyết định lâm sàng,Thử nghiệm lâm sàng ngẫu nhiên có đối chứng
# b Nếu các hoạt động dự phòng cấp hai có kết quả thì sẽ làm giảm: Thời gian phát triển trung bình của một bệnh
# c Nếu các hoạt động dự phòng cấp ba có kết quả thì sẽ làm giảm: Tỷ lệ mới mắc
# d Có một tỷ lệ nhỏ sau khi mắc bệnh sởi có thể bị mắc viêm não sơ cứng bán cấp gây rối loạn thần kinh tiến triển
# e Trong dự phòng cấp 1: Các biện pháp bảo vệ đặc hiệu bao gồm việc gây miễn dịch đặc hiệu, vệ sinh môi trường, các biện pháp bảo vệ chống các tai nạn xã hội…
# 14dac55d3cf44b408823991653e4dda2: Câu 303: Nguyên nhân của xu thế tăng giảm của bệnh có thể là: -> Nguyên nhân của xu thế tăng giảm của bệnh có thể là:
# c816e5cd2f864a3b856dc93377b88625: Câu 305:Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
#  a Sử dụng các tỷ lệ chết để So sánh đánh giá sức khoẻ cộng đồng
#  b Tỷ lệ tấn công là tỷ lệ mới nhiễm tích lũy của một bệnh trong một quần thể nhất định có nguy cơ trong thời gian đặc biệt, thường được sử dụng trong các vụ dịch
#  c Để có thể hình thành giả thuyết nhân quả phải tiến hành nghiên cứu:Hồi cứu
#  d Nguyên nhân của xu thế tăng giảm của bệnh có thể là: Các chất độc và dị nguyên
#  e Khi chưa có sự can thiệp ở mức độ cộng đồng, yếu tố quan trọng nhất quyết định tính chu kỳ của một số bệnh truyền nhiễm là: Cấu trúc tuổi khác nhau giữa các quần thể -> Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
#  a Sử dụng các tỷ lệ chết để So sánh đánh giá sức khoẻ cộng đồng
#  b Tỷ lệ tấn công là tỷ lệ mới nhiễm tích lũy của một bệnh trong một quần thể nhất định có nguy cơ trong thời gian đặc biệt, thường được sử dụng trong các vụ dịch
#  c Để có thể hình thành giả thuyết nhân quả phải tiến hành nghiên cứu:Hồi cứu
#  d Nguyên nhân của xu thế tăng giảm của bệnh có thể là: Các chất độc và dị nguyên
#  e Khi chưa có sự can thiệp ở mức độ cộng đồng, yếu tố quan trọng nhất quyết định tính chu kỳ của một số bệnh truyền nhiễm là: Cấu trúc tuổi khác nhau giữa các quần thể
# c1f2a514d8824717ab7983458de34e13: Câu 307: Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
#  a Báo cáo trường hợp bệnh là mô tả diễn biến của một nhóm bệnh cụ thể từ đó thấy được những vấn đề khác thường của bệnh và dẫn đến hình thành giả thuyết
#  b Nghiên cứu dịch tễ học mô tả có thể được lựa chọn khi cần: Đánh giá việc kiểm định các giả thuyết
#  c Khi chưa có sự can thiệp ở mức độ cộng đồng, yếu tố quan trọng nhất quyết định tính chu kỳ của một số bệnh truyền nhiễm là: Cấu trúc tuổi khác nhau giữa các quần thể
#  d Chọn mẫu nghiên cứu là lựa chọn ra một số cá thể từ quần thể nghiên cứu đã được xác định
#  e Quần thể nghiên cứu là tập hợp các cá thể có chung những đặc trưng mà ta nghiên cứu -> Các phát biểu sau đây là đúng hay Sai (Đúng thì tích vào đáp án đúng, sai thì tích vào đáp án sai)
#  a Báo cáo trường hợp bệnh là mô tả diễn biến của một nhóm bệnh cụ thể từ đó thấy được những vấn đề khác thường của bệnh và dẫn đến hình thành giả thuyết
#  b Nghiên cứu dịch tễ học mô tả có thể được lựa chọn khi cần: Đánh giá việc kiểm định các giả thuyết
#  c Khi chưa có sự can thiệp ở mức độ cộng đồng, yếu tố quan trọng nhất quyết định tính chu kỳ của một số bệnh truyền nhiễm là: Cấu trúc tuổi khác nhau giữa các quần thể
#  d Chọn mẫu nghiên cứu là lựa chọn ra một số cá thể từ quần thể nghiên cứu đã được xác định
#  e Quần thể nghiên cứu là tập hợp các cá thể có chung những đặc trưng mà ta nghiên cứu
# c1e6d51ec8d44eb69cabfd9bed8e8e00: Câu 312: Dịch tễ học mô tả bao gồm tất cả ,Ngoại Trừ: -> Dịch tễ học mô tả bao gồm tất cả ,Ngoại Trừ:
# a6e4bf1d6fc54c69b92de5fa00f6d553: Câu 322. Bản chất của hô hấp tế bào là gì? -> Bản chất của hô hấp tế bào là gì?
# 55e3344529494d9286d103119d58740d: Câu 324: Phương pháp chẩn đoán miễn dịch học trong bệnh ký sinh trùng có ưu điểm gì? -> Phương pháp chẩn đoán miễn dịch học trong bệnh ký sinh trùng có ưu điểm gì?
# 55e3344529494d9286d103119d58740d: ['A. 123', 'D. 135', 'B. 234', 'C. 235'] -> ['123', '135', '234', '235']
# edf40980bf2f46f485042e7d7d581ac5: Câu 33: Chọn một câu trả lời đúng. Dùng Acyclovir để điều trị thủy đậu: -> Chọn một câu trả lời đúng. Dùng Acyclovir để điều trị thủy đậu:
# df4d573440044eabb81275eb4d3d0563: Câu 33. Một phụ nữ đẻ được 4 tháng, đang cho con bú, chưa có kinh lại muốn được đặt vòng tránh thai: -> Một phụ nữ đẻ được 4 tháng, đang cho con bú, chưa có kinh lại muốn được đặt vòng tránh thai:
# becf6d4c4b4243489b3cf812046e56af: Câu 338. Kinh nguyệt trước kỳ, màu kinh đỏ tươi, số lượng nhiều thường do huyết nhiệt? -> Kinh nguyệt trước kỳ, màu kinh đỏ tươi, số lượng nhiều thường do huyết nhiệt?
# 0dc6d6040b5a44888f35e488bf76561a: Câu 34: Thể lâm sang thấp tim hay gặp nhất là: -> Thể lâm sang thấp tim hay gặp nhất là:
# cf94f3233cb84894b93a7f0bed9004b4: Câu 35: Thuốc giải biểu làm mất tân dịch nhiều nên không dùng cho phụ nữ sau sinh? -> Thuốc giải biểu làm mất tân dịch nhiều nên không dùng cho phụ nữ sau sinh?
# 1457ea4382584ad5818e06ca57517c27: Câu 35. Khi nói đến tá dược THUỐC MỠ thì Lanolin ngậm nước có chứa: -> Khi nói đến tá dược THUỐC MỠ thì Lanolin ngậm nước có chứa:
# 055b420aaec746caa68a796d80cff0df: Câu 35. Kim lẩy da cắm vào giữa giọt dung dịch trên mặt da tạo thành một góc: -> Kim lẩy da cắm vào giữa giọt dung dịch trên mặt da tạo thành một góc:
# ed9317ae9fe441c18e3c6b05a094f47f: Câu 350. Triệu chứng nào là hậu quả của thiếu enzym glucose 6 phosphatdehydrogenase ở màng hồng cầu? -> Triệu chứng nào là hậu quả của thiếu enzym glucose 6 phosphatdehydrogenase ở màng hồng cầu?
# 02d2802dbd914cb2bff0fb3bd9f3aabe: Câu 353:Các biện pháp sau đây được thực hiện để phòng bệnh lây qua đường hô hấp truyền từ động vật, ngoại trừ: -> Các biện pháp sau đây được thực hiện để phòng bệnh lây qua đường hô hấp truyền từ động vật, ngoại trừ:
# 15bb981e49b64f4e966948953a317b9e: Câu 356: Để phòng bệnh lây qua da, niêm mạc do súc vật truyền sang người, biện pháp nào sau đây là không đúng: -> Để phòng bệnh lây qua da, niêm mạc do súc vật truyền sang người, biện pháp nào sau đây là không đúng:
# 125a8d5a146c45a4ba2aeca8bf7ecb03: Câu 36: Các nhiệm vụ chính của bệnh viện, trừ: -> Các nhiệm vụ chính của bệnh viện, trừ:
# f1c09ae271544d209e3eb88204c54e5a: Câu 36: Ở bệnh nhân có u trung thất tim thường: -> Ở bệnh nhân có u trung thất tim thường:
# f201a13cd9d5473ea7260a51acf0416f: Câu 36: Thuốc phòng hen hay dùng nhất hiện nay là: -> Thuốc phòng hen hay dùng nhất hiện nay là:
# 7d3f61ecc1b04e75847613fe3c7613d6: Câu 36. Đọc kết quả Test nội bì sau thời gian là: -> Đọc kết quả Test nội bì sau thời gian là:
# ...
# c16ac5a731e64207b06244295c548241: Câu 46. Da ấn vào có vết lõm là do: -> Da ấn vào có vết lõm là do:
# baba05ff8ead4807bed6b4c65855e636: Câu 71: Tiếng nghe thổi tâm thu ở vùng bụng ngang rốn là chỉ dẫn có giá trị chẩn đoán: -> Tiếng nghe thổi tâm thu ở vùng bụng ngang rốn là chỉ dẫn có giá trị chẩn đoán:
# ff5e6b2082704646b139b6a65ed9805b: Câu 13: pH trung bình của nước tiểu là: -> pH trung bình của nước tiểu là:
# ff5e6b2082704646b139b6a65ed9805b: ['A. 7.0', 'B. 6.0', 'C. 8.0', 'D. 0.0'] -> ['7.0', '6.0', '8.0', '0.0']
# 1cf5ea64d4dd44afa57c982683e18bdf: Câu 32. Áp suất thẩm thấu của một dung dịch: -> Áp suất thẩm thấu của một dung dịch:
# f4030387e9ca493b8b491f29ce670d94: Câu 51. Sỏi niệu quản hình thành là do? -> Sỏi niệu quản hình thành là do?
# 814a2cbd38fb4fd8a80584524a298478: Câu 70. Tính chất của thận khí hư -> Tính chất của thận khí hư
# 5ce2155704b541da8000599cb16e1f56: Câu 109. Chọn đáp án đúng: Trong số các đáp án sau đây để điều trị viêm thận - bể thận cấp có biến chứng, hãy chỉ ra đáp không chính xác: -> Chọn đáp án đúng: Trong số các đáp án sau đây để điều trị viêm thận - bể thận cấp có biến chứng, hãy chỉ ra đáp không chính xác:
# a64090067cdf47b897b85015025f6109: ['A. tự hào', 'B. thích thú', 'C. chán', 'D. yêu'] -> ['tự hào', 'thích thú', 'chán', 'yêu']
# 9f0648d50a784b68bdc7a8bc6f62b704: Câu 64: cBB1 cho bội đội huấn luyện ngoài trời trong điều kiện mùa hè với nhiệt độ WBGT là 31° Thời gian tiếp xúc với nguồn nhiệt của bộ đội theo QCVN 26:2016/BYT nên là: -> cBB1 cho bội đội huấn luyện ngoài trời trong điều kiện mùa hè với nhiệt độ WBGT là 31° Thời gian tiếp xúc với nguồn nhiệt của bộ đội theo QCVN 26:2016/BYT nên là:
# 0fec1159b48b4454a57d74eb7d876f56: Câu 177: Tập vận động chủ động có trợ giúp nhằm -> Tập vận động chủ động có trợ giúp nhằm
# 0350209edf5548208f6bb0c4a0365f82: ['A. mắt', 'B. vai', 'C. bàn chân', 'D. mũi'] -> ['mắt', 'vai', 'bàn chân', 'mũi']
# 026f71a2c82a4375b59c52777a805bbf: Câu 14: Tăng đào thải creatinin gặp trong các trường hợp sinh, bệnh lí sau: -> Tăng đào thải creatinin gặp trong các trường hợp sinh, bệnh lí sau:
# 3cb4e633c1154468a6be64b3d490015a: Câu 286: Theo ước tính Việt nam năm 2010, ít hoạt động thể lực gây: -> Theo ước tính Việt nam năm 2010, ít hoạt động thể lực gây:
# da08ede41f264a3289cd181e34a56d06: Câu 057. A: Em gái tôi bị đau chân. B: ______________________ -> A: Em gái tôi bị đau chân. B: ______________________
# da08ede41f264a3289cd181e34a56d06: ['A. Cô ấy không nên đi chạy.', 'B. Bạn không nên ăn chúng.', 'C. Bạn nên ăn một bữa sáng lớn.', 'D. Bạn nên ở trong nhà hôm nay.'] -> ['Cô ấy không nên đi chạy.', 'Bạn không nên ăn chúng.', 'Bạn nên ăn một bữa sáng lớn.', 'Bạn nên ở trong nhà hôm nay.']
# 3d2afa9b15e54b74b6e19bcc6502aa3c: Câu 177: Tập vận động chủ động có trợ giúp nhằm? -> Tập vận động chủ động có trợ giúp nhằm?
# d02ed2ffe6754aae89e1b4f7380ded9e: Câu 2. Bệnh nhân nam, 25 tuổi, vào viện với lí do đau đột ngột phía sau vùng khuỷu tay (P) khi đang tập gym ở tư thế khuỷu tay duỗi. Khám thấy sưng nề phía trên mỏm khuỷu tay (P), kèm theo hạn chế động tác duỗi cẳng tay (P). Chụp X-quang không thấy có hình ảnh gãy xương, sai khớp vùng tổn thương. Hãy cho biết nghĩ nhiều đến tổn thương gân cơ nào? -> Bệnh nhân nam, 25 tuổi, vào viện với lí do đau đột ngột phía sau vùng khuỷu tay (P) khi đang tập gym ở tư thế khuỷu tay duỗi. Khám thấy sưng nề phía trên mỏm khuỷu tay (P), kèm theo hạn chế động tác duỗi cẳng tay (P). Chụp X-quang không thấy có hình ảnh gãy xương, sai khớp vùng tổn thương. Hãy cho biết nghĩ nhiều đến tổn thương gân cơ nào?
# f84d37dca9ca4d828791e802d21f9d27: Câu 173: Tập mạnh cơ giai đoạn mạnh tính chấn thương mô mềm làm như thế nào? -> Tập mạnh cơ giai đoạn mạnh tính chấn thương mô mềm làm như thế nào?
# 68c4c990fe6a47b7a5d2ef8a933e9597: Câu 450: Đối với bộ đội hành quân dã ngoại, giải pháp nào mang tính quyết định trong dự phòng say nóng -> Đối với bộ đội hành quân dã ngoại, giải pháp nào mang tính quyết định trong dự phòng say nóng
# 14e203affabc4117a809642a6ccf54fd: Câu 89. Khi chạy, chân chạm đất chịu bao nhiêu trọng lực? -> Khi chạy, chân chạm đất chịu bao nhiêu trọng lực?
# 37e8d29e7ddb4cfba627dd85583a03dc: ['A.hoạt động', 'B.activitie', 'C.healthy', 'D.active'] -> ['hoạt động', 'activitie', 'healthy', 'active']
# b585c99d8bdf4e3fbf1e3900af925f83: Câu 173: Tập mạnh cơ giai đoạn mạnh tính chấn thương mô mềm làm như thế nào? -> Tập mạnh cơ giai đoạn mạnh tính chấn thương mô mềm làm như thế nào?
# f986f335da8e4914a84bbf6e81f5d380: Câu 413: Một học viên lớp DHQY49, trong điều kiện WBGT=28,00C ngay sau khi chạy 3.000m, tần số mạch của học viên này ngay sau dùng chạy là 140 lần/phút. Sau khi nghỉ 3 phút, tần số mạch của đối tượng là 126 lần/phút. Ta có thể kết luận về khả năng thích nghi với cường độ hoạt động trên của đồng chí đó là: -> Một học viên lớp DHQY49, trong điều kiện WBGT=28,00C ngay sau khi chạy 3.000m, tần số mạch của học viên này ngay sau dùng chạy là 140 lần/phút. Sau khi nghỉ 3 phút, tần số mạch của đối tượng là 126 lần/phút. Ta có thể kết luận về khả năng thích nghi với cường độ hoạt động trên của đồng chí đó là:
# f800fd7457864dabba82ab90d89c086e: Câu 86.Người bệnh thở máy được tiến hành cai máy thở khi: -> Người bệnh thở máy được tiến hành cai máy thở khi:
# 483a3eb22f8140678aeefdc0abb9f073: Câu 112: Pasteur nghiên cứu tạo miễn dịch chống bệnh dại vào năm nào: -> Pasteur nghiên cứu tạo miễn dịch chống bệnh dại vào năm nào:
# 45ebdf3f1c6f4e1b912a4674f6b859e4: Câu 61: Có thể nói ai là người đặt nền móng cho môn khoa hoc ‘dịch tễ hoc’: -> Có thể nói ai là người đặt nền móng cho môn khoa hoc ‘dịch tễ hoc’:
# c8581f4ef08a444484f13e133e3f4a5d: Câu 87. HC bệnh lục kinh do ai viết -> HC bệnh lục kinh do ai viết
# c8581f4ef08a444484f13e133e3f4a5d: ['A. Diệp Thiên Sỹ', 'B. Ngô Cúc Thông', 'C. Lê Hữu Trác'] -> ['Diệp Thiên Sỹ', 'Ngô Cúc Thông', 'Lê Hữu Trác']
# 8042a56f4e8b4e9593d9e57a8dc289ed: ['A.1/3 trên mặt trước ngoài cắng tay', 'B. 1/3 trên mặt trước trong cẳng tay', 'C.1/3 giữa truớc ngoài cẳng tay', 'D.⅓ giữa trước trong cẳng tay'] -> ['1/3 trên mặt trước ngoài cắng tay', '1/3 trên mặt trước trong cẳng tay', '1/3 giữa truớc ngoài cẳng tay', '⅓ giữa trước trong cẳng tay']
# c7e5596ad1a447ea8b043988b3b76613: Câu 22: Hãy chọn một ý đúng/ đúng nhất trong những câu trả lời sau: Tiêm trong da, test lẩy da, tiêm dưới da, tiêm bắp nông, tiêm tīnh mạch lần lượt đâm kim với góc độ bao nhiêu: -> Hãy chọn một ý đúng/ đúng nhất trong những câu trả lời sau: Tiêm trong da, test lẩy da, tiêm dưới da, tiêm bắp nông, tiêm tīnh mạch lần lượt đâm kim với góc độ bao nhiêu:
# c7e5596ad1a447ea8b043988b3b76613: ['A.30-45°, 15-30°, 60-90°, 45°, 10-15°.', 'B.10-15°, 60-90°, 15 - 30°, 45°, 30 - 45°.', 'C. 45°, 15-30°, 30-45°, 60 -90°, 10 - 15°.', 'D. 10-15°, 45°, 30-45°, 60-90°, 15-30°.'] -> ['30-45°, 15-30°, 60-90°, 45°, 10-15°.', '10-15°, 60-90°, 15 - 30°, 45°, 30 - 45°.', '45°, 15-30°, 30-45°, 60 -90°, 10 - 15°.', '10-15°, 45°, 30-45°, 60-90°, 15-30°.']
# dd122f03b6f04f2bbc8e36d07f4fcf4b: Câu 38. Trước khi đưa người bệnh đi phẫu thuật, điều dưỡng viên phải: -> Trước khi đưa người bệnh đi phẫu thuật, điều dưỡng viên phải:
# edd0df47d94f41b189e2fb3934848bed: Câu 39. Khi dùng thuốc cho người bênh, điều dưỡng viên phải: -> Khi dùng thuốc cho người bênh, điều dưỡng viên phải:
# fab0e5912d8f40e1bd3434a3025c8e67: Câu 43. Hệ thống điều dưỡng trong bệnh viện bao gồm: -> Hệ thống điều dưỡng trong bệnh viện bao gồm:
# 4530c3b914f54849b91224bd87ca96a2: Câu 46. Chăm sóc NB toàn diện là nhiệm vụ của ai: -> Chăm sóc NB toàn diện là nhiệm vụ của ai:
# d12e0d63f30a4cbca2efc24f4d8e5a54: Câu 56. Để giao tiếp có hiệu quả, trước hết điều dưỡng viên cần phải xác định : -> Để giao tiếp có hiệu quả, trước hết điều dưỡng viên cần phải xác định :
# 9daacb22442a4968b993ac81678e8d6c: Câu 38. Trước khi đưa người bệnh đi phẫu thuật, điều dưỡng viên phải: -> Trước khi đưa người bệnh đi phẫu thuật, điều dưỡng viên phải:
# aa3b4a781f45458c99b5580f85d35a49: Câu 39. Khi dùng thuốc cho người bênh, điều dưỡng viên phải: -> Khi dùng thuốc cho người bênh, điều dưỡng viên phải:
# ec7da25b538e4fc9aa95dfd1bca6c62d: Câu 56. Để giao tiếp có hiệu quả, trước hết điều dưỡng viên cần phải xác định : -> Để giao tiếp có hiệu quả, trước hết điều dưỡng viên cần phải xác định :
# 70f1d08a951745229610e58a31fab433: Câu 15: Chẩn đoán Fasciolopsis buski chắc chắn nếu -> Chẩn đoán Fasciolopsis buski chắc chắn nếu
# 5f8157e4fd364a1997280f301996a09a: Câu 16. Ở bệnh nhân tiêu chảy tái đi tái lại nghi nhiễm Fasciolopsis buski. Để quyết định chẩn đoán chúng ta -> Ở bệnh nhân tiêu chảy tái đi tái lại nghi nhiễm Fasciolopsis buski. Để quyết định chẩn đoán chúng ta
# 50421b39a5bc4b1b9404c50f6dcced44: Câu 30: Nội dung của dự phòng cấp ba đối với ung thư vú là: -> Nội dung của dự phòng cấp ba đối với ung thư vú là:
# ca8d90d8883a4d5aaedf104d4c124351: Câu 5: Đâu không phải là nôi dung chăm sóc bênh nhân ung thư ? -> Đâu không phải là nôi dung chăm sóc bênh nhân ung thư ?
# ca8d90d8883a4d5aaedf104d4c124351: ['A: Chăm sóc sức khỏe thể chất', 'B: Chăm sóc sức khỏe tinh thần', 'C: Chăm sóc sức khỏe sinh lí', 'D: Chăm sóc sức khỏe liên tục'] -> ['Chăm sóc sức khỏe thể chất', 'Chăm sóc sức khỏe tinh thần', 'Chăm sóc sức khỏe sinh lí', 'Chăm sóc sức khỏe liên tục']
# 27779a51dcac4232a516e0dd8f870720: ['A. Đúng', 'B. Sai'] -> ['Đúng', 'Sai']
# f941b24562c8476895505ceaff46a09b: ['A. tê', 'B. bị sốc', 'C. sợ hãi', 'D. cô lập'] -> ['tê', 'bị sốc', 'sợ hãi', 'cô lập']
# 4622b42850924078b6c73be3c8936886: ['A. Đúng', 'B. Sai'] -> ['Đúng', 'Sai']
# 514138368ae4494ba643af7980e26891: Câu 24: Theo nghiên cứu của Kubler – Ross (1970),giai đoạn II trong tâm lý thường gặp của bệnh nhân trước khi chết là gì? -> Theo nghiên cứu của Kubler – Ross (1970),giai đoạn II trong tâm lý thường gặp của bệnh nhân trước khi chết là gì?
# 49b24ad7479a4c72a543ced051ca331a: ['A. bị sốc', 'B. bị tê liệt', 'C. từ chức', 'D. phủ nhận'] -> ['bị sốc', 'bị tê liệt', 'từ chức', 'phủ nhận']
# ea431b3ff8c6401dac8d4550d43bafe1: ['A. Nắm bắt bệnh sử chi tiết, khám cẩn thận để xác định nguồn gốc cơn đau, mức độ', 'B. Giải thích tỉ mỉ và thực hiện phương pháp kết hợp thể chất và tâm lý người bệnh, phương điều trị dùng thuốc và không dùng thuốc', 'C. Dùng thuốc đúng liều, đúng thời gian', 'D. Cả 3 đáp án trên.'] -> ['Nắm bắt bệnh sử chi tiết, khám cẩn thận để xác định nguồn gốc cơn đau, mức độ', 'Giải thích tỉ mỉ và thực hiện phương pháp kết hợp thể chất và tâm lý người bệnh, phương điều trị dùng thuốc và không dùng thuốc', 'Dùng thuốc đúng liều, đúng thời gian', 'Cả 3 đáp án trên.']
# 995d14f2c6d347bdb186ceae09b03946: Câu 1: Chọn câu trả lời đúng và đầy đủ nhất về « Khái niệm đau » -> Chọn câu trả lời đúng và đầy đủ nhất về « Khái niệm đau »
# a293099af6304b479e84220251d368db: ['A. từ chối', 'B. giữ', 'C. giữ', 'D. đối phó với'] -> ['từ chối', 'giữ', 'giữ', 'đối phó với']
# 6df87fc50112461e8f7bf694a35cbe02: ['A. Đúng', 'B. Sai'] -> ['Đúng', 'Sai']
# 47c09d8800ce43ffb0ef55fe5569bd70: Câu 25:Theo nghiên cứu của Kubler – Ross (1970),giai đoạn III trong tâm lý thường gặp của bệnh nhân trước khi chết là gì? -> Theo nghiên cứu của Kubler – Ross (1970),giai đoạn III trong tâm lý thường gặp của bệnh nhân trước khi chết là gì?
# 3757be6fc8b9410e9824f78a215201f8: ['A. Đúng', 'B. Sai'] -> ['Đúng', 'Sai']
# f8170363541a4f9980378f8c57f27fca: Câu 7: Điều trị theo chuyên khoa là chăm sóc sức khỏe về thể chất đúng hay sai ? -> Điều trị theo chuyên khoa là chăm sóc sức khỏe về thể chất đúng hay sai ?
# f8170363541a4f9980378f8c57f27fca: ['A:Đúng', 'B: Sai'] -> ['Đúng', 'Sai']
# 3062fcab27f14bc7bb6b52247ad3ad8d: ['A morphin,codein', 'B Codein,tramadol', 'C Tramadol,morphin', 'D Codein,fentanyl'] -> ['morphin,codein', 'Codein,tramadol', 'Tramadol,morphin', 'Codein,fentanyl']
# a562f8a32c7840789baa58b33f48afa7: Câu 17: Theo WHO, thuốc nào KHÔNG dùng trong bước 2- đau trung bình -? -> Theo WHO, thuốc nào KHÔNG dùng trong bước 2- đau trung bình -?
# fbc532dba56047b4bef311174db68241: ['A. Pethidine (C15N2NO21)', 'B. Fentanyl(C22H28N2O)', 'C. Methadone(C21H27NO)', 'D. Amphetamin(C₁,H13N)'] -> ['Pethidine (C15N2NO21)', 'Fentanyl(C22H28N2O)', 'Methadone(C21H27NO)', 'Amphetamin(C₁,H13N)']
# ae093870ac8242f5ab04c79298970185: Câu 115. Quy luật giản lược của Gestalt có mấy tính chất? -> Quy luật giản lược của Gestalt có mấy tính chất?
# 05b12bfa481c4e6e84549c20e50c54a7: Câu 117. Có bao nhiêu loại chú ý? -> Có bao nhiêu loại chú ý?
# 23404646c4be447f8e938efd3172c28e: Câu 16: Dựa vào số lượng bệnh nhân tham gia, người ta có những cách phân loại liệu pháp tâm lý nào? -> Dựa vào số lượng bệnh nhân tham gia, người ta có những cách phân loại liệu pháp tâm lý nào?
# 96ff958ab6264c04aad9e6618e7b3f18: ['A.Liều chết của Cocain cho người lớn khoảng 1 g', 'B.Cocain hydroclorid là dạng không phổ biến trên thị trường', 'C.Người nghiện hay dùng dưới dạng tiêm', 'D.Khi dùng lâu gây nghiện dẫn đến thể lựcvà trí tuệ suy tàn'] -> ['Liều chết của Cocain cho người lớn khoảng 1 g', 'Cocain hydroclorid là dạng không phổ biến trên thị trường', 'Người nghiện hay dùng dưới dạng tiêm', 'Khi dùng lâu gây nghiện dẫn đến thể lựcvà trí tuệ suy tàn']
# c60adc4fc80e46159934668a842ca2b0: Câu 11. Đặc điểm KHÔNG ĐÚNG của Nitrazepam: -> Đặc điểm KHÔNG ĐÚNG của Nitrazepam:
# effbd4ae93854305bc9ff18858c4dc58: Câu 376. Người thông minh có sự đề kháng với thuyết phục yếu hơn người kém thông minh? -> Người thông minh có sự đề kháng với thuyết phục yếu hơn người kém thông minh?
# 6a55d0263c534d2ba97c9097c1f27220: Câu 5: Không chẩn đoán phân biệt rối loạn phổ tự kỷ theo DSM 5 với -> Không chẩn đoán phân biệt rối loạn phổ tự kỷ theo DSM 5 với
# 3dc83dbd0bf740b68c6686ee10d815e7: Câu 6 Có nhiều loại thuốc an thần được sử dụng để điều trị tâm thần phân liệt, rối loạn lưỡng cực, loạn thần do ma túy... Các thuốc an thần đều có thể gây ra tác dụng phụ ngoại tháp. Thuốc an thần nào trong số các thuốc sau ít nguy cơ gây ngoại tháp nhất? Hãy chọn câu trả lời đúng nhất! -> Có nhiều loại thuốc an thần được sử dụng để điều trị tâm thần phân liệt, rối loạn lưỡng cực, loạn thần do ma túy... Các thuốc an thần đều có thể gây ra tác dụng phụ ngoại tháp. Thuốc an thần nào trong số các thuốc sau ít nguy cơ gây ngoại tháp nhất? Hãy chọn câu trả lời đúng nhất!
# 1d86bd2532054c5d9513c77141b39118: Câu 10: Đan sâm không có tác dụng dưỡng tâm an thần? -> Đan sâm không có tác dụng dưỡng tâm an thần?
# ba364bb66b934d31af252e9352b4dcd9: Câu 21: Kubler – Ross (1970)là một trong những ít người nghiên cứu tâm lý về cái chết, những nghiên cứu đó của bà được thực hiện trên nhóm người bệnh nào? -> Kubler – Ross (1970)là một trong những ít người nghiên cứu tâm lý về cái chết, những nghiên cứu đó của bà được thực hiện trên nhóm người bệnh nào?
# 2c68f48225d841c8ad3a25ed0048aae4: Câu 348. Nỗi buồn có liên quan đến sự giảm hoạt động một số vùng ở vỏ não? -> Nỗi buồn có liên quan đến sự giảm hoạt động một số vùng ở vỏ não?
# 814b7385a98e40fcb55f91e6870c65e9: Câu 339. Vai trò quan trọng nhất của cảm xúc? -> Vai trò quan trọng nhất của cảm xúc?
# e660bb998ae1488486644d28d69c7456: Câu 41 Khoảng 40% bệnh nhân trầm cảm sẽ có các rối loạn lo âu đi kèm. Các bệnh nhân này 40 | rất khó điều trị vì đáp ứng kém với thuốc chống trầm cảm. Để tăng hiệu quả điều trị, người ta thường kết hợp với một nhóm thuốc khác. Nhóm thuốc nào hay được kết hợp trong , điều trị trầm cảm có các rối loạn lo âu đi kèm? Hãy chọn câu trả lời đúng nhất! -> Khoảng 40% bệnh nhân trầm cảm sẽ có các rối loạn lo âu đi kèm. Các bệnh nhân này 40 | rất khó điều trị vì đáp ứng kém với thuốc chống trầm cảm. Để tăng hiệu quả điều trị, người ta thường kết hợp với một nhóm thuốc khác. Nhóm thuốc nào hay được kết hợp trong , điều trị trầm cảm có các rối loạn lo âu đi kèm? Hãy chọn câu trả lời đúng nhất!
# {'id': 'd29c07eb35614948bd3bda4f04bbfe44', 'difficulty_level': 'Easy', 'medical_topic': ['Toxicology', 'Emergency Medicine'], 'question': '_________ từ cá nóc gây tê liệt, sưng tấy và buồn nôn.', 'options': ['thuốc độc', 'bị đầu độc', 'độc hại', 'ngộ độc'], 'option_map': [0, 1, 2, 3], 'answer': 'A', 'answer_index': 0}
# Final len: 5304

# %%
len(rows)
# Out:
# 5304

# %%
rows[0]
# Out:
# {'id': 'd29c07eb35614948bd3bda4f04bbfe44',
#  'difficulty_level': 'Easy',
#  'medical_topic': ['Toxicology', 'Emergency Medicine'],
#  'question': '_________ từ cá nóc gây tê liệt, sưng tấy và buồn nôn.',
#  'options': ['thuốc độc', 'bị đầu độc', 'độc hại', 'ngộ độc'],
#  'option_map': [0, 1, 2, 3],
#  'answer': 'A',
#  'answer_index': 0}

# %%
with open(output_path, 'w') as f:
    for row in rows:
        json.dump(row, f, ensure_ascii=False)
        f.write('\n')

# %%
import random

def shuffle_options(row):
    try:
        new_option_map: list[int] = row["option_map"].copy()
        random.shuffle(new_option_map)
        # 2 3 1 0
        # 0 1 2 3
        # 2

        # Build new row with shuffled options and updated answer_index
        new_row = row.copy()
        new_row["options"] = [row["options"][i] for i in new_option_map]
        new_row["option_map"] = new_option_map
        new_row["answer_index"] = new_option_map.index(row["answer_index"])
        new_row["answer"] = chr(new_row["answer_index"] + ord('A'))
        return new_row
    except Exception as e:
        print(row)
        print(len(row["options"]))
        print(e)

# %%
shuffled_rows = [shuffle_options(row) for row in rows]
shuffled_rows = list(filter(lambda row: row is not None, shuffled_rows))
with open(shuffled_path, 'w') as f:
    for row in shuffled_rows:
        json.dump(row, f, ensure_ascii=False)
        f.write('\n')

shuffled_rows = [shuffle_options(row) for row in rows]
shuffled_rows = list(filter(lambda row: row is not None, shuffled_rows))
with open(shuffled_path2, 'w') as f:
    for row in shuffled_rows:
        json.dump(row, f, ensure_ascii=False)
        f.write('\n')

# %%
raise ""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 raise ""
#
# TypeError: exceptions must derive from BaseException

# %%
import pandas as pd

# Load the Excel file
excel_file_path = "mc.xlsx"
df = pd.read_excel(excel_file_path)

# Save the DataFrame to a CSV file
csv_file_path = "mc.csv"
df.to_csv(csv_file_path, index=False)
